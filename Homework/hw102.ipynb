# %%
from google.colab import drive
# 將自己的雲端硬碟掛載上去
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
cd '/content/gdrive/My Drive/2020-ml100marathon-final-exam/image_data/'
# Out:
# /content/gdrive/My Drive/2020-ml100marathon-final-exam/image_data

# %%
import os
import glob
import shutil
# import matplotlib.pyplot as plt
# import tensorflow as tf
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import numpy as np
# from tensorflow.keras.optimizers import Adam
# from tensorflow.keras.layers import Activation,BatchNormalization

# from tensorflow.keras.regularizers import l2
# from tensorflow.keras.callbacks import LearningRateScheduler
# from tensorflow.keras.callbacks import ReduceLROnPlateau

base_dir =  "./train"
num_classes = 5
classes = ['daisy', 'dandelion', 'rose', 'sunflower', 'tulip']

# %%
for cl in classes:
  img_path = os.path.join(base_dir, cl)                          # 取得單一類別資料夾路徑
  images = glob.glob(img_path + '/*.jpg')                        # 載入所有 jpg 檔成為一個 list
  print("{}: {} Images".format(cl, len(images)))                 # 印出單一類別有幾張圖片
  num_train = int(round(len(images)*0.8))                        # 切割 80% 資料作為訓練集
  train, val = images[:num_train], images[num_train:]            # 訓練 > 0~80%，驗證 > 80%~100%

  for t in train:
    if not os.path.exists(os.path.join(base_dir, 'train', cl)):  # 如果資料夾不存在
      os.makedirs(os.path.join(base_dir, 'train', cl))           # 建立新資料夾
    shutil.move(t, os.path.join(base_dir, 'train', cl))          # 搬運圖片資料到新的資料夾

  for v in val:
    if not os.path.exists(os.path.join(base_dir, 'val', cl)):    # 如果資料夾不存在
      os.makedirs(os.path.join(base_dir, 'val', cl))             # 建立新資料夾
    shutil.move(v, os.path.join(base_dir, 'val', cl))            # 搬運圖片資料到新的資料夾
    
train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')
# Out:
# daisy: 0 Images
# dandelion: 0 Images
# rose: 0 Images
# sunflower: 0 Images
# tulip: 0 Images

# %%
train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')

IMG_SHAPE=150
batch_size=256

image_gen_train = ImageDataGenerator(
    rescale=1./255,               # 從0~255整數，壓縮為0~1浮點數
    rotation_range=45,            # 隨機旋轉 ±45°
    width_shift_range=.15,        # 隨機水平移動 ±15%
    height_shift_range=.15,       # 隨機垂直移動 ±15%
    horizontal_flip=True,         # 隨機水平翻轉
    zoom_range=0.5                # 隨機縮放 50%
)


train_data_gen = image_gen_train.flow_from_directory(
    batch_size=batch_size,
    directory=train_dir,
    shuffle=True,
    target_size=(IMG_SHAPE,IMG_SHAPE),
    class_mode='categorical'  
    )

image_gen_val = ImageDataGenerator(
    rescale=1./255,               # 從0~255整數，壓縮為0~1浮點數
    rotation_range=45,            # 隨機旋轉 ±45°
    width_shift_range=.15,        # 隨機水平移動 ±15%
    height_shift_range=.15,       # 隨機垂直移動 ±15%
    horizontal_flip=True,         # 隨機水平翻轉
    zoom_range=0.5                # 隨機縮放 50%
    )

val_data_gen = image_gen_val.flow_from_directory(
    batch_size=batch_size,
    directory=val_dir,
    target_size=(IMG_SHAPE, IMG_SHAPE),
    class_mode='categorical'
)
# Out:
# Found 2258 images belonging to 5 classes.
# Found 565 images belonging to 5 classes.

# %%
from keras.models import load_model
from sklearn.datasets import load_files   
from keras.utils import np_utils
from glob import glob
from keras import applications
from keras.preprocessing.image import ImageDataGenerator 
from keras import optimizers
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Dense, Dropout, Flatten, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import BatchNormalization, Concatenate, GlobalMaxPooling2D
from keras.callbacks import ReduceLROnPlateau, LambdaCallback, ModelCheckpoint, LearningRateScheduler, EarlyStopping

# 訓練用的超參數

input_shape=(IMG_SHAPE, IMG_SHAPE, 3)

# 架構主要 model

main_model = Sequential()

resnet_model = applications.resnet_v2.ResNet50V2(include_top=False, pooling='avg', weights='imagenet', input_shape=input_shape)
main_model.add(resnet_model)

# 想辦法讓訓練不要這麼飄
#main_model.add(BatchNormalization())
#main_model.add(Dense(2048, activation='relu'))
#main_model.add(BatchNormalization())
#main_model.add(Dense(1024, activation='relu'))
#main_model.add(Dropout(0.5))
#main_model.add(Flatten())
main_model.add(Dense(num_classes, activation='softmax'))
main_model.summary()

# 因為是遷移學習，本來就有訓練了，縮小 learning rate，才不會讓訓練好的成果跑掉
opt = optimizers.Adam(lr=1e-4)
main_model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# 檢查是否凍結 ALL
print("--檢查 ALL 是否凍結-----------------")
for layer in main_model.layers:
    print(layer.name, ' is trainable? ', layer.trainable)

main_model.summary()


# 訓練模型囉！

# checkpoint 儲存最好的一個

# shutil.rmtree('best_loss', ignore_errors=True)
if not os.path.exists('best_loss'):
  os.makedirs('best_loss')

# tensorflow v2 val_acc -> val_accuracy
weight_path="./best_loss/epoch_{epoch:02d}_val_acc_{val_accuracy:.4f}_val_loss_{val_loss:.4f}.h5"
best_weight_path = "./best_weight.h5"

ck_epoch_weight = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1,
                                          save_weights_only=True,
                                          save_best_only=True,
                                          mode='min')

ck_best_weight = ModelCheckpoint(best_weight_path, monitor='val_loss', verbose=1,
                                        save_weights_only=True,
                                        save_best_only=True,
                                        mode='min')

# 使用自動降低學習率 (當 validation loss 連續 5 次沒有下降時，自動降低學習率)
lr_reducer = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.8,
    patience=5,
    verbose=1,
    mode='auto',
    min_delta=0.0001,
    cooldown=5,
    min_lr=1e-14)

early = EarlyStopping(monitor="val_loss", mode="min", patience=10) # probably needs to be more patient, but kaggle time is limited

# 學習率動態調整。當跑到第幾個 epcoh 時，根據設定修改學習率。這邊的數值都是參考原 paper
def lr_schedule(epoch):
    lr = 1e-4
    if epoch > 500:
        lr = 1e-7
    elif epoch > 200:
        lr = 1e-6
    elif epoch > 100:
        lr = 1e-5
    print('Learning rate: ', lr)
    return lr

lr_scheduler = LearningRateScheduler(lr_schedule)

# 設定 callbacks
callbacks = [ck_epoch_weight, ck_best_weight, lr_reducer,early]

epochs = 80

history = main_model.fit(
    train_data_gen,
    epochs=epochs,
    validation_data=val_data_gen,
    callbacks=callbacks,
    workers=2
)

main_model.save('my_model')
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23564800
# _________________________________________________________________
# dense_18 (Dense)             (None, 5)                 10245
# =================================================================
# Total params: 23,575,045
# Trainable params: 23,529,605
# Non-trainable params: 45,440
# _________________________________________________________________
# --檢查 ALL 是否凍結-----------------
# resnet50v2  is trainable?  True
# dense_18  is trainable?  True
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23564800
# _________________________________________________________________
# dense_18 (Dense)             (None, 5)                 10245
# =================================================================
# Total params: 23,575,045
# Trainable params: 23,529,605
# Non-trainable params: 45,440
# _________________________________________________________________
# Epoch 1/80
# 2/9 [=====>........................] - ETA: 4s - loss: 1.8875 - accuracy: 0.2285WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.4371s vs `on_train_batch_end` time: 0.7353s). Check your callbacks.
# 9/9 [==============================] - ETA: 0s - loss: 1.2316 - accuracy: 0.5159
# Epoch 00001: val_loss improved from inf to 0.98135, saving model to ./best_loss/epoch_01_val_acc_0.6425_val_loss_0.9813.h5
#
# Epoch 00001: val_loss improved from inf to 0.98135, saving model to ./best_weight.h5
# 9/9 [==============================] - 31s 3s/step - loss: 1.2316 - accuracy: 0.5159 - val_loss: 0.9813 - val_accuracy: 0.6425
# Epoch 2/80
# 9/9 [==============================] - ETA: 0s - loss: 0.6080 - accuracy: 0.7777
# Epoch 00002: val_loss improved from 0.98135 to 0.88948, saving model to ./best_loss/epoch_02_val_acc_0.7310_val_loss_0.8895.h5
#
# Epoch 00002: val_loss improved from 0.98135 to 0.88948, saving model to ./best_weight.h5
# 9/9 [==============================] - 24s 3s/step - loss: 0.6080 - accuracy: 0.7777 - val_loss: 0.8895 - val_accuracy: 0.7310
# Epoch 3/80
# 9/9 [==============================] - ETA: 0s - loss: 0.4266 - accuracy: 0.8388
# Epoch 00003: val_loss did not improve from 0.88948
#
# Epoch 00003: val_loss did not improve from 0.88948
# 9/9 [==============================] - 23s 3s/step - loss: 0.4266 - accuracy: 0.8388 - val_loss: 0.9343 - val_accuracy: 0.7593
# Epoch 4/80
# 9/9 [==============================] - ETA: 0s - loss: 0.3567 - accuracy: 0.8782
# Epoch 00004: val_loss improved from 0.88948 to 0.88061, saving model to ./best_loss/epoch_04_val_acc_0.7929_val_loss_0.8806.h5
#
# Epoch 00004: val_loss improved from 0.88948 to 0.88061, saving model to ./best_weight.h5
# 9/9 [==============================] - 25s 3s/step - loss: 0.3567 - accuracy: 0.8782 - val_loss: 0.8806 - val_accuracy: 0.7929
# Epoch 5/80
# 9/9 [==============================] - ETA: 0s - loss: 0.3023 - accuracy: 0.8888
# Epoch 00005: val_loss did not improve from 0.88061
#
# Epoch 00005: val_loss did not improve from 0.88061
# 9/9 [==============================] - 23s 3s/step - loss: 0.3023 - accuracy: 0.8888 - val_loss: 1.0201 - val_accuracy: 0.7752
# Epoch 6/80
# 9/9 [==============================] - ETA: 0s - loss: 0.2341 - accuracy: 0.9198
# Epoch 00006: val_loss did not improve from 0.88061
#
# Epoch 00006: val_loss did not improve from 0.88061
# 9/9 [==============================] - 23s 3s/step - loss: 0.2341 - accuracy: 0.9198 - val_loss: 0.8850 - val_accuracy: 0.7876
# Epoch 7/80
# 9/9 [==============================] - ETA: 0s - loss: 0.2150 - accuracy: 0.9287
# Epoch 00007: val_loss improved from 0.88061 to 0.69104, saving model to ./best_loss/epoch_07_val_acc_0.8336_val_loss_0.6910.h5
#
# Epoch 00007: val_loss improved from 0.88061 to 0.69104, saving model to ./best_weight.h5
# 9/9 [==============================] - 25s 3s/step - loss: 0.2150 - accuracy: 0.9287 - val_loss: 0.6910 - val_accuracy: 0.8336
# Epoch 8/80
# 9/9 [==============================] - ETA: 0s - loss: 0.1823 - accuracy: 0.9349
# Epoch 00008: val_loss improved from 0.69104 to 0.65507, saving model to ./best_loss/epoch_08_val_acc_0.8248_val_loss_0.6551.h5
#
# Epoch 00008: val_loss improved from 0.69104 to 0.65507, saving model to ./best_weight.h5
# 9/9 [==============================] - 25s 3s/step - loss: 0.1823 - accuracy: 0.9349 - val_loss: 0.6551 - val_accuracy: 0.8248
# Epoch 9/80
# 9/9 [==============================] - ETA: 0s - loss: 0.1529 - accuracy: 0.9482
# Epoch 00009: val_loss improved from 0.65507 to 0.60483, saving model to ./best_loss/epoch_09_val_acc_0.8637_val_loss_0.6048.h5
#
# Epoch 00009: val_loss improved from 0.65507 to 0.60483, saving model to ./best_weight.h5
# 9/9 [==============================] - 25s 3s/step - loss: 0.1529 - accuracy: 0.9482 - val_loss: 0.6048 - val_accuracy: 0.8637
# Epoch 10/80
# 9/9 [==============================] - ETA: 0s - loss: 0.1327 - accuracy: 0.9570
# Epoch 00010: val_loss did not improve from 0.60483
#
# Epoch 00010: val_loss did not improve from 0.60483
# 9/9 [==============================] - 23s 3s/step - loss: 0.1327 - accuracy: 0.9570 - val_loss: 0.6308 - val_accuracy: 0.8460
# Epoch 11/80
# 9/9 [==============================] - ETA: 0s - loss: 0.1079 - accuracy: 0.9641
# Epoch 00011: val_loss improved from 0.60483 to 0.54869, saving model to ./best_loss/epoch_11_val_acc_0.8531_val_loss_0.5487.h5
#
# Epoch 00011: val_loss improved from 0.60483 to 0.54869, saving model to ./best_weight.h5
# 9/9 [==============================] - 25s 3s/step - loss: 0.1079 - accuracy: 0.9641 - val_loss: 0.5487 - val_accuracy: 0.8531
# Epoch 12/80
# 9/9 [==============================] - ETA: 0s - loss: 0.1071 - accuracy: 0.9646
# Epoch 00012: val_loss did not improve from 0.54869
#
# Epoch 00012: val_loss did not improve from 0.54869
# 9/9 [==============================] - 23s 3s/step - loss: 0.1071 - accuracy: 0.9646 - val_loss: 0.5978 - val_accuracy: 0.8496
# Epoch 13/80
# 9/9 [==============================] - ETA: 0s - loss: 0.0919 - accuracy: 0.9743
# Epoch 00013: val_loss did not improve from 0.54869
#
# Epoch 00013: val_loss did not improve from 0.54869
# 9/9 [==============================] - 23s 3s/step - loss: 0.0919 - accuracy: 0.9743 - val_loss: 0.5871 - val_accuracy: 0.8407
# Epoch 14/80
# 9/9 [==============================] - ETA: 0s - loss: 0.0781 - accuracy: 0.9765
# Epoch 00014: val_loss did not improve from 0.54869
#
# Epoch 00014: val_loss did not improve from 0.54869
# 9/9 [==============================] - 22s 2s/step - loss: 0.0781 - accuracy: 0.9765 - val_loss: 0.5766 - val_accuracy: 0.8496
# Epoch 15/80
# 9/9 [==============================] - ETA: 0s - loss: 0.0711 - accuracy: 0.9779
# Epoch 00015: val_loss did not improve from 0.54869
#
# Epoch 00015: val_loss did not improve from 0.54869
# 9/9 [==============================] - 22s 2s/step - loss: 0.0711 - accuracy: 0.9779 - val_loss: 0.6174 - val_accuracy: 0.8425
# Epoch 16/80
# 9/9 [==============================] - ETA: 0s - loss: 0.0657 - accuracy: 0.9787
# Epoch 00016: val_loss did not improve from 0.54869
#
# Epoch 00016: val_loss did not improve from 0.54869
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 7.999999797903001e-05.
# 9/9 [==============================] - 23s 3s/step - loss: 0.0657 - accuracy: 0.9787 - val_loss: 0.6249 - val_accuracy: 0.8478
# Epoch 17/80
# 9/9 [==============================] - ETA: 0s - loss: 0.0656 - accuracy: 0.9783
# Epoch 00017: val_loss did not improve from 0.54869
#
# Epoch 00017: val_loss did not improve from 0.54869
# 9/9 [==============================] - 23s 3s/step - loss: 0.0656 - accuracy: 0.9783 - val_loss: 0.6415 - val_accuracy: 0.8407
# Epoch 18/80
# 9/9 [==============================] - ETA: 0s - loss: 0.0574 - accuracy: 0.9801
# Epoch 00018: val_loss did not improve from 0.54869
#
# Epoch 00018: val_loss did not improve from 0.54869
# 9/9 [==============================] - 23s 3s/step - loss: 0.0574 - accuracy: 0.9801 - val_loss: 0.5709 - val_accuracy: 0.8513
# Epoch 19/80
# 9/9 [==============================] - ETA: 0s - loss: 0.0542 - accuracy: 0.9858
# Epoch 00019: val_loss did not improve from 0.54869
#
# Epoch 00019: val_loss did not improve from 0.54869
# 9/9 [==============================] - 22s 2s/step - loss: 0.0542 - accuracy: 0.9858 - val_loss: 0.6426 - val_accuracy: 0.8673
# Epoch 20/80
# 9/9 [==============================] - ETA: 0s - loss: 0.0471 - accuracy: 0.9836
# Epoch 00020: val_loss did not improve from 0.54869
#
# Epoch 00020: val_loss did not improve from 0.54869
# 9/9 [==============================] - 22s 2s/step - loss: 0.0471 - accuracy: 0.9836 - val_loss: 0.6064 - val_accuracy: 0.8496
# Epoch 21/80
# 9/9 [==============================] - ETA: 0s - loss: 0.0435 - accuracy: 0.9867
# Epoch 00021: val_loss did not improve from 0.54869
#
# Epoch 00021: val_loss did not improve from 0.54869
# 9/9 [==============================] - 23s 3s/step - loss: 0.0435 - accuracy: 0.9867 - val_loss: 0.5833 - val_accuracy: 0.8566
# INFO:tensorflow:Assets written to: my_model/assets

# %%
from tensorflow import keras
main_model = keras.models.load_model("./my_model")

# %%
main_model.load_weights("best_weight.h5")

# %%
import os

folderPath = "./test"
testFolder = os.listdir(folderPath)
fileName = []
prediction_class = []

import tensorflow as tf

for file in testFolder:
  filePath = os.path.join(folderPath,file)
#filePate = "./test/240f4db86a37d8b932b7496cc71d7699.jpg"
  image = tf.keras.preprocessing.image.load_img(filePath,target_size=(IMG_SHAPE,IMG_SHAPE))
  input_arr = tf.keras.preprocessing.image.img_to_array(image)
#input_arr = np.array([input_arr])  # Convert single image to a batch.
#print(input_arr)
#predictions = main_model.predict(input_arr)

#print(predictions)

  predicted = np.argmax(main_model.predict(np.expand_dims(input_arr, axis=0)))

  print(predicted)

  prediction_class.append(predicted)
  fileName.append(file.replace(".jpg", ""))

  print("image: %s, class: %d" %(file, predicted))
# Out:
# 0
# image: d827f37ad27a3a827728f44854ad89d1.jpg, class: 0
# 0
# image: c982b784597d423549969c62f1da6a02.jpg, class: 0
# 0
# image: ccc0dfbbc932c678fe3a84973de1785e.jpg, class: 0
# 0
# image: f28196eb9916fe38bf1dcdb8cf6acd4e.jpg, class: 0
# 0
# image: dade47153d9d7bae211ad59e6c15f0c6.jpg, class: 0
# 0
# image: f4b1503b311ca0706f8eb8bdb5eb39be.jpg, class: 0
# 0
# image: cc9d37b04fb596b3113e3182bf31db47.jpg, class: 0
# 0
# image: cd6c2e66fc0039ecf99744f6078d8d80.jpg, class: 0
# 0
# image: d34ca5a677756886db4a02336818d356.jpg, class: 0
# 0
# image: d59371c0c0d3f1a01737f37f94693807.jpg, class: 0
# 0
# image: cf1bff0c0742ef1d8ef5b378ee7bbbcc.jpg, class: 0
# 0
# image: f3bb5ec9e74226e8f324ef431ae04afd.jpg, class: 0
# 0
# image: e228d31ce171a667728b4547a1854bd4.jpg, class: 0
# 0
# image: f6572d14ee1c3fcb2c299c4b610748bc.jpg, class: 0
# 0
# image: ee23c329a5bdb7a53feca32c816d7a3d.jpg, class: 0
# 0
# image: f862db487bb05e503c29c17bf35f5825.jpg, class: 0
# 0
# image: ee92e7d67f468b101e4ac74a32a845c7.jpg, class: 0
# 0
# image: e642800f08d1724f014f320beef2f055.jpg, class: 0
# 0
# image: e28c54dbcc27d710c4e4e0b862369c69.jpg, class: 0
# 0
# image: cb1846e480e30ecadd9558995c41878a.jpg, class: 0
# 0
# image: e824304dc94f1d8d9dd8342569354573.jpg, class: 0
# 0
# image: f4252aa28723e9e240c37cb4783886c4.jpg, class: 0
# 0
# image: d4ca75068a94297606294e495de50985.jpg, class: 0
# 0
# image: ca1f76759ff55d70cb48050fcade17e6.jpg, class: 0
# 0
# image: f88b94be254fd0bd024991e005945c01.jpg, class: 0
# 0
# image: ff3df418b948dbbe61d45cced4260107.jpg, class: 0
# 0
# image: caec58508b0aba1954adf6633d818244.jpg, class: 0
# 0
# image: f8bf4c1a105397ba45f963102a2f005c.jpg, class: 0
# 0
# image: fb5b0ec7d1f60866a8807f572aac03e8.jpg, class: 0
# 0
# image: f6524250b8217eefa9a7cb89663b2f9f.jpg, class: 0
# 0
# image: d5f3abe9065d79089593e1860b6e195e.jpg, class: 0
# 0
# image: f1fa785e5a542dc3bfeceec7089b5e7e.jpg, class: 0
# 0
# image: f6a224537c270d497307caacfe163881.jpg, class: 0
# 0
# image: cfa2d06918ad04b49944055aff56beaf.jpg, class: 0
# 0
# image: e5cefc09f126b8bcb58e9ab145ce5593.jpg, class: 0
# 0
# image: cfa7a311344a1f0aa377784e78e8002c.jpg, class: 0
# 0
# image: cfbeed32cfd782f85cc3c78b74d7ea81.jpg, class: 0
# 0
# image: ddf3d10d2906e92961aa2cb334ba52c9.jpg, class: 0
# 0
# image: f0437714213089ecf4060081495b13d4.jpg, class: 0
# 0
# image: f1179823ca6973aa7c815ef3c698c71c.jpg, class: 0
# 0
# image: f2d6abf86c6894f89763683919e7bdad.jpg, class: 0
# 0
# image: d0ee2297b487adeae84d28abe7dba94c.jpg, class: 0
# 0
# image: dfdc4798b3fdda420303165ebc42db8d.jpg, class: 0
# 0
# image: e65ab3f299ac8bbca15881a2ea284776.jpg, class: 0
# 0
# image: ce3b0bd83828403cb800fb51746a37bc.jpg, class: 0
# 0
# image: f9aadb1a44b9666f5d996f5b4049e45f.jpg, class: 0
# 0
# image: d1eeb2ab656553cb3539e18a1c48c032.jpg, class: 0
# 0
# image: d8caa3d5f6c1373f472a22cd82fe877d.jpg, class: 0
# 0
# image: fa73922f692fb9963fde167524de0832.jpg, class: 0
# 0
# image: fd9cac41cda00325613b362025eb9cc1.jpg, class: 0
# 0
# image: fb4fb25aaf7a339c73536891174a26a1.jpg, class: 0
# 0
# image: df699742f8d36817add8a3763ca8ae4d.jpg, class: 0
# 0
# image: fef84518e3118b231928869a6b36e94e.jpg, class: 0
# 0
# image: c7d8d5af9acfb389c8ec93b637e12b2e.jpg, class: 0
# 0
# image: f71874a53fbb1211ccf8711c554d17ea.jpg, class: 0
# 0
# image: dfc5527bc55497562c389480b4a8ffd1.jpg, class: 0
# 0
# image: daf03f7ae5dfd7902c3d5be2fe6de6e4.jpg, class: 0
# 0
# image: dd4c9739d38eaa57326d51951113bd5d.jpg, class: 0
# 0
# image: e66fa5946b0c8cd96f68a90a36f8ac25.jpg, class: 0
# 0
# image: f6978ff0f46a1db7c7a380750b491048.jpg, class: 0
# 0
# image: f951d216ab537320621d6e5a676f90f2.jpg, class: 0
# 0
# image: e73b1ad30b9596483ffa72e4133779d9.jpg, class: 0
# 0
# image: fa636f8cbc6984cc9e702fe0e2484476.jpg, class: 0
# 0
# image: e86789078f3731bdc3d1e740825f29b3.jpg, class: 0
# 0
# image: ef5e7c74ff5658466603fc7310ae7919.jpg, class: 0
# 0
# image: f68982758320e33ef7c8693a006594f1.jpg, class: 0
# 0
# image: eb6781459aa007d43284ac7b3d1d9c05.jpg, class: 0
# 0
# image: e24ec4c2526f6608f98a84cc92004ab5.jpg, class: 0
# 0
# image: ddb940b6137accd4ae1fcd6b23dcb2bf.jpg, class: 0
# 0
# image: e7dbef40b1de16b27e49cafb73754d76.jpg, class: 0
# 0
# image: d769b700b61707a12cec49f97b2b7d29.jpg, class: 0
# 0
# image: f8677278bfb394346e6bfbb05593f4b8.jpg, class: 0
# 0
# image: f9ddd5af01c53e08e37a1ca12112d7a5.jpg, class: 0
# 0
# image: ff5ed4106759efd6fc5eb97ea8babf0b.jpg, class: 0
# 0
# image: ca429d21a16ffa0c47059008bcc9666f.jpg, class: 0
# 0
# image: dd03034f4c8cb8bd19088a1e1fa56e92.jpg, class: 0
# 0
# image: dfd0f65abfe098226f9c7f864676f72e.jpg, class: 0
# 0
# image: f8536c1d61896d1fc1e989ee006e7b6e.jpg, class: 0
# 0
# image: f82917047e23fa424ec56ad9b96777ef.jpg, class: 0
# 0
# image: f9b5254ddc08b637e3eaefb58dd5ba79.jpg, class: 0
# 0
# image: e4e9c1121d8e27cc7a1037d1399d35ae.jpg, class: 0
# 0
# image: d56061d5a18a2a6338d91c6e56b8b3d3.jpg, class: 0
# 0
# image: ced18931468c4332f1995236f3b7ab5c.jpg, class: 0
# 0
# image: edb8c3b7837e7238d18ecbcda18620a4.jpg, class: 0
# 0
# image: e862bb5cd86b49568d69e333dfd94cad.jpg, class: 0
# 0
# image: ef1a93a741c0543f89cf2dec56812e0f.jpg, class: 0
# 0
# image: f2077f19eef500da676a2a4f861ceaa1.jpg, class: 0
# 0
# image: d9ed954b28c1d10b3fae363775b6f997.jpg, class: 0
# 0
# image: df016944b885993ae1a8b3def618effd.jpg, class: 0
# 0
# image: d8185ca6dea0fcdb575f721002a1b845.jpg, class: 0
# 0
# image: e0d53b7e43ea36c5c84ac9d2fd87d13e.jpg, class: 0
# 0
# image: e3c9e6ed4efb14ba5ab72ca60803ec3e.jpg, class: 0
# 0
# image: cdccad861e8870165b247887306e2f1b.jpg, class: 0
# 0
# image: cff1215ab5b2b6d2c5ebf32c9366b3aa.jpg, class: 0
# 0
# image: e738efa98c775a887595275261deb424.jpg, class: 0
# 0
# image: e33deb7ad894cc3110cc4e01012f03fa.jpg, class: 0
# 0
# image: e7eed90ba27d842d9c63ddba24af4e32.jpg, class: 0
# 0
# image: dd41a5bd4f115c5101814f909c378248.jpg, class: 0
# 0
# image: ee85126308bdbdcdfeaf76ca2b9f3498.jpg, class: 0
# 0
# image: f209bc542a12be79ebf2a644ebe270e9.jpg, class: 0
# 0
# image: d1628767872cfc25d83ffbd08e6ef97c.jpg, class: 0
# 0
# image: e8c2207a28da82e1c02fa13a3448dbc0.jpg, class: 0
# 0
# image: ea294e77105ce15eadbf875ac83b4cde.jpg, class: 0
# 0
# image: dfea4ff837039f5e1295327964fd79d9.jpg, class: 0
# 0
# image: fbaa56cc8703f040b2d2b3a7cb3686c4.jpg, class: 0
# 0
# image: f825e3df237f402f744352c269ba98fc.jpg, class: 0
# 0
# image: ec149891a04ff64dd979c0a0d220f426.jpg, class: 0
# 0
# image: df2be4c9ce5ed1d765fb0fcae3815f78.jpg, class: 0
# 0
# image: e36c93483c01072a2ce9fab0093f9a88.jpg, class: 0
# 0
# image: ea5b797ba9529a0b8c5ff7fa434108b1.jpg, class: 0
# 0
# image: ee0fbb964894825c72c6f0c2937c8832.jpg, class: 0
# 0
# image: edc1ae7e01ffab863064cd7005ac4a8b.jpg, class: 0
# 0
# image: ea18cb9311359acc2986913dba6edbf8.jpg, class: 0
# 0
# image: e588a640458629d08b4a4ad8936f2a34.jpg, class: 0
# 0
# image: f5ed00c5c306a23af3a8248a6d26cbd0.jpg, class: 0
# 0
# image: effe1cf8525b887419cd0f3b5690273a.jpg, class: 0
# 0
# image: f394ca61016b7c8a46f953264a6ecfdb.jpg, class: 0
# 0
# image: e700c5b6f1348e1d64308ba333512590.jpg, class: 0
# 0
# image: fd11bc5c6a044023c6bcb6e35ff794ef.jpg, class: 0
# 0
# image: faf0abe1290c9555110ca051be5495fa.jpg, class: 0
# 0
# image: c888448e96c094501f37d299473f067f.jpg, class: 0
# 0
# image: dc5d37c53ef4a9333160f4275d173434.jpg, class: 0
# 0
# image: e910da596d6154eb7ade04de2a2ad180.jpg, class: 0
# 0
# image: e2b5e396a9125a2f8e1a6f2a48db545a.jpg, class: 0
# 0
# image: d8bd8de131fda7d2ef63a36b9c378166.jpg, class: 0
# 0
# image: ca42f8b4afce69912d13259d79d0e13d.jpg, class: 0
# 0
# image: f5fbd751dcb328274865533d846129d4.jpg, class: 0
# 0
# image: ee148aefdd6d5e76f2dba6a55c0de3df.jpg, class: 0
# 0
# image: e868ec6b33fd2eb62837eb680c919d14.jpg, class: 0
# 0
# image: dc735c5ca24ece5151e7b3a380281a63.jpg, class: 0
# 0
# image: c8f1d97d9ebb666b422025df7ad7fd6c.jpg, class: 0
# 0
# image: e3e54d841e675d7962e8c801629e5e06.jpg, class: 0
# 0
# image: f5d164257e875304721587f16b903db6.jpg, class: 0
# 0
# image: ce2e9a92fa06bc5163be86ed895cb89d.jpg, class: 0
# 0
# image: fde1d5fa8f5209108ba11252a1466e5e.jpg, class: 0
# 0
# image: fb9b745c6fa27e0106282cda009ec144.jpg, class: 0
# 0
# image: f0b6ecfa7c4981cc5a89789ceb283ebd.jpg, class: 0
# 0
# image: ecfb0c8bcef4462b3dc574e81af05e79.jpg, class: 0
# 0
# image: d0454e3aa9160530cb0b52dd0f878335.jpg, class: 0
# 0
# image: e38259beb4a959a77f1b3019e2d41fec.jpg, class: 0
# 0
# image: c9bfc65f36fbab1411bdd6b0ebd6c0bc.jpg, class: 0
# 0
# image: e916b2b54c0be480866501a497bee256.jpg, class: 0
# 0
# image: df1dee70c899d5fef2df9c829c7e1372.jpg, class: 0
# 0
# image: fea9d31e49b014ecedb876a726a990d1.jpg, class: 0
# 0
# image: f0b7a19147f7de6b252eff303edc56ef.jpg, class: 0
# 0
# image: fbf8038dbe6aa10516f519b2f719c9e1.jpg, class: 0
# 0
# image: dee2871444a34e87b97960d0785d980a.jpg, class: 0
# 0
# image: f52c1faa5ae2142aec01df82ea5c9219.jpg, class: 0
# 0
# image: e48d95ab366816c0d843b4fdf2ac8780.jpg, class: 0
# 0
# image: f06d5a81746f6fd5a8d0b6c2c335d0e9.jpg, class: 0
# 0
# image: cbf03ecf593e9f570a3e8c24d1f62d0a.jpg, class: 0
# 0
# image: ffea1f275c05accb0a6bfd1203620c7e.jpg, class: 0
# 0
# image: d3a8fdb0934a98d00fd7be76b1efc8a5.jpg, class: 0
# 0
# image: fda7085f5d8b6f995922b19f5aeec873.jpg, class: 0
# 0
# image: e10299e094206c00a680a589285111a7.jpg, class: 0
# 0
# image: fd2580a8f500b27baf6913759b29c003.jpg, class: 0
# 0
# image: f76df1b165b345492bd072f6a4fa4502.jpg, class: 0
# 0
# image: ce2ab19704b54017f6fd78b14917c491.jpg, class: 0
# 0
# image: caa61e7bf2f5347fe9586cf69afa4fb6.jpg, class: 0
# 0
# image: e233ca2f65f2e0824cd391f36c0f636e.jpg, class: 0
# 0
# image: fbcc7a2d563db710395edede6872783f.jpg, class: 0
# 0
# image: eae74966793f20bdc4d8e0546cbcaa61.jpg, class: 0
# 0
# image: fdb273780ac1826aef9de8c6a2d425f4.jpg, class: 0
# 0
# image: f49e74d9cc932fa8f2caa90f17a4f0c6.jpg, class: 0
# 0
# image: dba5bd6fddf6d753f1f64c6e5e2dc247.jpg, class: 0
# 0
# image: ee831ce53e14fa364298ac4aac0ceda5.jpg, class: 0
# 0
# image: d0a28e5068232ed4cb8287ab9162d4c4.jpg, class: 0
# 0
# image: c7d7d404dfd52206b9e638b460aa21e5.jpg, class: 0
# 0
# image: f5d718bf756a0870633c88d6c52078ec.jpg, class: 0
# 0
# image: cf3700251127de116e7d0d4e9ab15aa8.jpg, class: 0
# 0
# image: e813966532a161a9393e696b1f3ea22b.jpg, class: 0
# 0
# image: ffbc32a7b67dfe72b8d35d4b1b35fd6c.jpg, class: 0
# 0
# image: fe64b09b1e78de73cc137ce86402a096.jpg, class: 0
# 0
# image: cbdd82d57e22fd1336e7a4aa7eb18cee.jpg, class: 0
# 0
# image: fe829d2d57b3363eee1126d7a93737d9.jpg, class: 0
# 0
# image: d7719b5501892d822dceb7736fe045b5.jpg, class: 0
# 0
# image: e548276854f2e53ae457ba1f770f1e66.jpg, class: 0
# 0
# image: d76df78250617ea69b6e2e109a83e24a.jpg, class: 0
# 0
# image: e911063d94fa427c9fde81df4fbab627.jpg, class: 0
# 0
# image: d55e0fdd28b84a2a9eb061c4cd459b02.jpg, class: 0
# 0
# image: fc819b994c00eca1e22915766fb1acb0.jpg, class: 0
# 0
# image: d2880e07730f3b7880bec90455ff8fc1.jpg, class: 0
# 0
# image: e28dec5e4ee9866ccb229c55634bdec0.jpg, class: 0
# 0
# image: dfa78c45042d5ed92d6f7a8e3aec925c.jpg, class: 0
# 0
# image: f51d3257c68cff1ec5f87eb6b6bea193.jpg, class: 0
# 0
# image: f5f99620e326073d5a95ec345297cf29.jpg, class: 0
# 0
# image: f4e00007aec4c689e600118e6bb2239d.jpg, class: 0
# 0
# image: f96ed079cd0289265963fb72a574de78.jpg, class: 0
# 0
# image: dcd92723ff6c111c0f97d1592d1aca3a.jpg, class: 0
# 0
# image: c88712845ca3ac99bd54250c3db7ba2f.jpg, class: 0
# 0
# image: e01d2fba3f4c48a1450725a45771f6c6.jpg, class: 0
# 0
# image: e1f67db801183244cc585f2e0c0734ec.jpg, class: 0
# 0
# image: e452276a5c9ee325348b8d57f3e3c7d4.jpg, class: 0
# 0
# image: f3987094fe9952792f194f9e66001c60.jpg, class: 0
# 0
# image: d242ca6ec9d3c693b7d853adaa34af4b.jpg, class: 0
# 0
# image: f67554d92b5a9401f6eae23b3db1281f.jpg, class: 0
# 0
# image: ef617fb6dba4f8852d0d588dcd6d37a8.jpg, class: 0
# 0
# image: ffefcc68e2e7eed8b17b0b5b0f740538.jpg, class: 0
# 0
# image: df0979856a546b7459705fde518bc03d.jpg, class: 0
# 0
# image: f8043282b3ad39e91ad4ac02c2d809af.jpg, class: 0

# %%
import pandas  as pd


sub = pd.DataFrame({'id': fileName, 'flower_class': prediction_class})

sub.to_csv('final_exam_tesh.csv', index=False)
